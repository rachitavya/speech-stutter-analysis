# %%
import os
import pathlib
import subprocess
import requests
import numpy as np
from pydub import AudioSegment
import librosa
import soundfile as sf

# %%
episode_uri = 'SEP-28k_episodes.csv'
wav_dir ='[WAV_DIR]'

# %%
table = np.loadtxt(episode_uri, dtype=str, delimiter=",")
urls = table[:,2]
n_items = len(urls)

audio_types = [".mp3", ".m4a", ".mp4"]

# %%
for i in range(n_items):
    # Get show/episode IDs
    show_abrev = table[i,-2]
    ep_idx = table[i,-1]
    episode_url = table[i,2]
    ext = ''
    for ext in audio_types:
        if ext in episode_url:
            break
    episode_dir = pathlib.Path(f"{wav_dir}/{show_abrev}/")
    os.makedirs(episode_dir, exist_ok=True)

    # Get file paths
    audio_path_orig = pathlib.Path(f"{episode_dir}/{ep_idx}{ext}")
    wav_path = pathlib.Path(f"{episode_dir}/{ep_idx}.wav")
    # Check if this file has already been downloaded
    if os.path.exists(wav_path):
        continue

    print("Processing", show_abrev, ep_idx)
    # Download raw audio file. This could be parallelized.
    if not os.path.exists(audio_path_orig):
        print(f"Downloading {episode_url} to {audio_path_orig}")
        response = requests.get(episode_url)
        if response.status_code == 200:
            with open(audio_path_orig, 'wb') as file:
                file.write(response.content)
                print('hello')
    else:
        print(f"File {audio_path_orig} already exists, skipping download.")

    # Convert to 16khz mono wav file
    # Replace with the path to your audio file
    audio, sample_rate = librosa.load(audio_path_orig, sr=None)  # sr=None to preserve the original sample rate

    # Resample to 16kHz
    target_sample_rate = 16000
    audio = librosa.resample(audio,orig_sr=sample_rate,target_sr= target_sample_rate)
    
    # Convert to mono (if not already)
    if audio.ndim == 2:
        audio = librosa.to_mono(audio)

    # Save as a WAV file
    sf.write(wav_path, audio, target_sample_rate)

    print(f"Audio file saved to {wav_path}")

        
    os.remove(audio_path_orig)
# Out:
# Processing  HeStutters  1
# Downloading  https://stutterrockstar.files.wordpress.com/2012/04/male-episode-10-with-landon.mp3 to [WAV_DIR]\ HeStutters\ 1.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 1.wav
# Processing  HeStutters  2
# Downloading  https://stutterrockstar.files.wordpress.com/2012/05/male-episode-11-with-frank.mp3 to [WAV_DIR]\ HeStutters\ 2.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 2.wav
# Processing  HeStutters  3
# Downloading  https://stutterrockstar.files.wordpress.com/2012/05/male-episode-12-with-lott1.mp3 to [WAV_DIR]\ HeStutters\ 3.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 3.wav
# Processing  HeStutters  4
# Downloading  https://stutterrockstar.files.wordpress.com/2012/06/male-episode-13-with-juan-ali.mp3 to [WAV_DIR]\ HeStutters\ 4.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 4.wav
# Processing  HeStutters  5
# Downloading  https://stutterrockstar.files.wordpress.com/2012/08/male-episode-14-with-grant.mp3 to [WAV_DIR]\ HeStutters\ 5.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 5.wav
# Processing  HeStutters  6
# Downloading  https://stutterrockstar.files.wordpress.com/2012/08/male-episode-15-with-hanan.mp3 to [WAV_DIR]\ HeStutters\ 6.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 6.wav
# Processing  HeStutters  7
# Downloading  https://stutterrockstar.files.wordpress.com/2012/09/male-episode-16-with-geoff.mp3 to [WAV_DIR]\ HeStutters\ 7.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 7.wav
# Processing  HeStutters  8
# Downloading  https://stutterrockstar.files.wordpress.com/2012/09/male-episode-17-with-robert.mp3 to [WAV_DIR]\ HeStutters\ 8.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 8.wav
# Processing  HeStutters  9
# Downloading  https://stutterrockstar.files.wordpress.com/2012/11/male-episode-18-with-ray.mp3 to [WAV_DIR]\ HeStutters\ 9.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 9.wav
# Processing  HeStutters  10
# Downloading  https://stutterrockstar.files.wordpress.com/2012/11/male-episode-19-with-john-h.mp3 to [WAV_DIR]\ HeStutters\ 10.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 10.wav
# Processing  HeStutters  11
# Downloading  https://stutterrockstar.files.wordpress.com/2011/07/male-episode-2-with-henryk.mp3 to [WAV_DIR]\ HeStutters\ 11.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 11.wav
# Processing  HeStutters  12
# Downloading  https://stutterrockstar.files.wordpress.com/2014/02/male-episode-20-with-oli.mp3 to [WAV_DIR]\ HeStutters\ 12.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 12.wav
# Processing  HeStutters  13
# Downloading  https://stutterrockstar.files.wordpress.com/2014/08/male-episode-21-with-dylan.mp3 to [WAV_DIR]\ HeStutters\ 13.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 13.wav
# Processing  HeStutters  14
# Downloading  https://stutterrockstar.files.wordpress.com/2016/09/male-episode-22-w-chaz.mp3 to [WAV_DIR]\ HeStutters\ 14.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 14.wav
# Processing  HeStutters  15
# Downloading  https://stutterrockstar.files.wordpress.com/2017/06/male-episode-23-with-ian.mp3 to [WAV_DIR]\ HeStutters\ 15.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 15.wav
# Processing  HeStutters  16
# Downloading  https://stutterrockstar.files.wordpress.com/2018/09/male-episode-24-with-david-a.mp3 to [WAV_DIR]\ HeStutters\ 16.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 16.wav
# Processing  HeStutters  17
# Downloading  https://stutterrockstar.files.wordpress.com/2018/09/male-episode-25-with-rob.mp3 to [WAV_DIR]\ HeStutters\ 17.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 17.wav
# Processing  HeStutters  18
# Downloading  https://stutterrockstar.files.wordpress.com/2018/11/male-episode-26-with-andy-fitz.mp3 to [WAV_DIR]\ HeStutters\ 18.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 18.wav
# Processing  HeStutters  19
# Downloading  https://stutterrockstar.files.wordpress.com/2020/04/male-episode-27-with-chris-c.mp3 to [WAV_DIR]\ HeStutters\ 19.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 19.wav
# Processing  HeStutters  20
# Downloading  https://stutterrockstar.files.wordpress.com/2011/10/male-episode-3-with-vivek.mp3 to [WAV_DIR]\ HeStutters\ 20.mp3
# hello
# Audio file saved to [WAV_DIR]\ HeStutters\ 20.wav
# Processing  HeStutters  21
# Downloading  https://stutterrockstar.files.wordpress.com/2012/01/male-episode-4-with-joseph.mp3 to [WAV_DIR]\ HeStutters\ 21.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 24
#      22 if not os.path.exists(audio_path_orig):
#      23     print(f"Downloading {episode_url} to {audio_path_orig}")
# ---> 24     response = requests.get(episode_url)
#      25     if response.status_code == 200:
#      26         with open(audio_path_orig, 'wb') as file:
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~\anaconda3\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\anaconda3\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\lib\http\client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~\anaconda3\lib\http\client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(wav_path,audio_path_orig)
# Out:
# [WAV_DIR]\ HeStutters\ 0.wav [WAV_DIR]\ HeStutters\ 0.mp3
